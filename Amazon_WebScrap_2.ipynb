# %% [markdown]
# <a href="https://colab.research.google.com/github/Arvin-007Elite/ML-Projects/blob/master/Amazon_WebScrap_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
url = 'https://www.amazon.in/LG-Frost-Free-Inverter-Refrigerator-GL-B257HDSY/dp/B0BX4FBVQB/ref=sr_1_1?_encoding=UTF8&content-id=amzn1.sym.bebdace2-678b-4d50-bc1f-da5ce25f5500&dib=eyJ2IjoiMSJ9.1N9m7WYBqmJBkkf-GZIeLoAw61dV6frnyo5di3Y7D_xdm3kSHJdqTfA3j_Pvk5PgbDD26zvxda2_hQayfbyNlIJpXdN47U0RFChGMt-xOvDO2JAD92wgiwbJWpZL-BcY_49HmslcJPKVFqtRp7E7Nlz5WrWlyELvohQ_2KG5qVavcGIyn9KJ2bnYheRfs09dJ-qVPQOa--Oj8N-4t5TX0bd0CidNP10N0xiy_7XtHD2p3XmHcNNdZ1hpzh-hqp9Zze_lJlogk1kxkqV_JVgUAsRDD0VBWpCK7l29oz1xTE0.Bk3j9TJ780Ha2Dt1BRaZLEP26odRaOrzV5IZywg4H00&dib_tag=se&pd_rd_r=9407ba09-a46f-4032-aee9-0e1dc81e3267&pd_rd_w=3oQLV&pd_rd_wg=5jvqk&pf_rd_p=bebdace2-678b-4d50-bc1f-da5ce25f5500&pf_rd_r=E15QKBXVNFQEVAXEMC9Q&qid=1729421937&refinements=p_85%3A10440599031%2Cp_n_feature_seven_browse-bin%3A85105228031%2Cp_n_feature_sixteen_browse-bin%3A65990132031%7C88657472031&rps=1&s=kitchen&sr=1-1'

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# %%
page = requests.get(url , headers= headers)

soup = BeautifulSoup(page.content , "html.parser")

print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->
# <!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->
# <!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="a-no-js" lang="en-us"><!--<![endif]--><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title dir="ltr">Amazon.in</title>
# <meta content="width=device-width" name="viewport"/>
# <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
# <script>
#
# if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
# ...

# %%
# Printing Prettified Data
soup2 = BeautifulSoup(soup.prettify() , "html.parser")

soup2
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->
# <!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->
# <!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="a-no-js" lang="en-us">
# <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title dir="ltr">
#    Amazon.in
#   </title>
# <meta content="width=device-width" name="viewport"/>
# <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
# <script>
#    if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
# ...

# %%
title = soup.find_all('div')
title
# Out:
# [<div class="a-container a-padding-double-large" style="min-width:350px;padding:44px 0 !important">
#  <div class="a-row a-spacing-double-large" style="width: 350px; margin: 0 auto">
#  <div class="a-row a-spacing-medium a-text-center"><i class="a-icon a-logo"></i></div>
#  <div class="a-box a-alert a-alert-info a-spacing-base">
#  <div class="a-box-inner">
#  <i class="a-icon a-icon-alert"></i>
#  <h4>Enter the characters you see below</h4>
#  <p class="a-last">Sorry, we just need to make sure you're not a robot. For best results, please make sure your browser is accepting cookies.</p>
#  </div>
#  </div>
#  <div class="a-section">
#  <div class="a-box a-color-offset-background">
#  <div class="a-box-inner a-padding-extra-large">
#  <form action="/errors/validateCaptcha" method="get" name="">
# ...

# %%
heading = [word.text.strip() for word in title]

heading
# Out:
# ["Enter the characters you see below\nSorry, we just need to make sure you're not a robot. For best results, please make sure your browser is accepting cookies.\n\n\n\n\n\n\n\n\n\n\nType the characters you see in this image:\n\n\n\n\n\n\n\n\n\nTry different image\n\n\n\n\n\n\n\n\n\n\n\nContinue shopping\n\n\n\n\n\n\n\n\n\n\n\nConditions of Use & Sale\n\n\n\n\nPrivacy Notice\n\n\n          © 1996-2015, Amazon.com, Inc. or its affiliates",
#  "Enter the characters you see below\nSorry, we just need to make sure you're not a robot. For best results, please make sure your browser is accepting cookies.\n\n\n\n\n\n\n\n\n\n\nType the characters you see in this image:\n\n\n\n\n\n\n\n\n\nTry different image\n\n\n\n\n\n\n\n\n\n\n\nContinue shopping",
#  '',
#  "Enter the characters you see below\nSorry, we just need to make sure you're not a robot. For best results, please make sure your browser is accepting cookies.",
# ...

# %%
title = soup2.find(id='productTitle').get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-72bd9dd011a8> in <cell line: 1>()
# ----> 1 soup2.find(id='productTitle').get_text()
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
Price = soup2.find(id='productPrice').get_text()

# %%
print(title)
print(Price)
# if wth more space , continue steps down

# %%
Price.strip()
# spaces will cut and print  , if its printed with dollar , we can cut that
Price.strip()[1:]
# this prints values only after 1st index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-64d7a033ce0d> in <cell line: 1>()
# ----> 1 Price.strip()
#       2 # spaces will cut and print  ,
#
# NameError: name 'Price' is not defined

# %%
# we just got a product and its price

# %%
import datetime

today = datetime.date.today()
print(today)
#getting date

# %%
import csv

header = ['Title' , 'Price' , 'Date']
data = [title , Price , today]

with open('AmazonWebScraperDataset.csv' , 'w' , newline='' , encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)
    # run his csv will be created

# %%
# now we can read the file and see

# %%
with open('AmazonWebScraperDataset.csv' , 'w' , newline='' , encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)
    # appending new dats under old datss gain & again (not new ) , just for exampling

  # and run above cell , csv will be updated

# %%
# Automating this for everyday

def check_price():
    URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, "html.parser")

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup2.find(id='productTitle').get_text()

    price = soup2.find(id='priceblock_ourprice').get_text()

    price = price.strip()[1:]
    title = title.strip()

    import datetime

    today = datetime.date.today()

    import csv

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
while(True):
    check_price()
    time.sleep(5)
    # every 5 seconds this function runs and add the data (reason is to check the price)
    # if its varies , we can know that in csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-bcb6d1b6bae3> in <cell line: 1>()
#       1 while(True):
# ----> 2     check_price()
#       3     time.sleep(5)
#       4     # every 5 seconds this function runs and add the data (reason is to check the price)
#
# NameError: name 'check_price' is not defined

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\HP\AmazonWebScraperDataset.csv')

print(df)

# %%
# If uou want to try sending yourself an email (just for fun) when a price hits below a certain level you can try it
# out with this script

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('arvinkritik2@gmail.com','xxxxxxxxxxxxxx')

    subject = "The Shirt you want is below $15! Now is your chance to buy!"
    body = "Arvin, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data+analyst+tshirt&qid=1626655184&sr=8-3"

    msg = f"Subject: {subject}\n\n{body}"

    server.sendmail(
        'arvinkritik2@gmail.com',
        msg

    )
